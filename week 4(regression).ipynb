# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\faruk hussai\anaconda3\lib\site-packages (1.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: joblib>=1.1.1 in c:\users\faruk hussai\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\faruk hussai\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\faruk hussai\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\faruk hussai\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %%
URL = "https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt"

diabetes = pd.read_csv("https://www4.stat.ncsu.edu/~boos/var.select/diabetes.tab.txt")

# %%
diabetes.head()
# Out:
#         AGE\tSEX\tBMI\tBP\tS1\tS2\tS3\tS4\tS5\tS6\tY
# 0  59\t2\t32.1\t101\t157\t93.2\t38\t4\t4.8598\t87...
# 1  48\t1\t21.6\t87\t183\t103.2\t70\t3\t3.8918\t69...
# 2  72\t2\t30.5\t93\t156\t93.6\t41\t4\t4.6728\t85\...
# 3  24\t1\t25.3\t84\t198\t131.4\t40\t5\t4.8903\t89...
# 4  50\t1\t23\t101\t192\t125.4\t52\t4\t4.2905\t80\...

# %%
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
X = X[:, np.newaxis, 2]

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()

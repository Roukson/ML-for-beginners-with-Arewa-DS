# %%
import pandas as pd
import matplotlib as plt

# %%
birds = pd.read_csv(r"C:\Users\FARUK HUSSAI\Documents\GitHub\ML-for-beginners-with-Arewa-DS\datasets\birds.csv")

# %%
birds.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
birds.isnull().sum()
# Out:
# Name                  0
# ScientificName        0
# Category              0
# Order                 0
# Family                0
# Genus                 0
# ConservationStatus    0
# MinLength             0
# MaxLength             0
# MinBodyMass           0
# MaxBodyMass           0
# MinWingspan           0
# MaxWingspan           0
# dtype: int64

# %%
wingspan = birds['MaxWingspan'] 
wingspan.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ASSIGNMENT 1

# %%
birds[birds["Name"]== "Snow_goose"]
birds.plot()
# Out:
# <AxesSubplot:>

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(birds.MaxWingspan, birds.MaxLength)
plt.title("Snow goose info")
plt.show()

# %% [markdown]
# ASSIGNMENT 2(proportions)

# %%
pip install pywaffle
# Out:
# ...
#
# ...

# %% [markdown]
# assignment 3 (relationship)

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
honey = pd.read_csv(r"C:\Users\FARUK HUSSAI\Documents\GitHub\ML-for-beginners-with-Arewa-DS\datasets\honey.csv")

# %%
honey.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
honey["totalprod"]
# Out:
# 0       1136000.0
# 1       3300000.0
# 2       3445000.0
# 3      37350000.0
# 4       1944000.0
#           ...
# 621      164000.0
# 622     2542000.0
# 623      288000.0
# 624     4140000.0
# 625     2550000.0
# Name: totalprod, Length: 626, dtype: float64

# %%
sns.relplot(x="year", y="totalprod", kind="line", data=honey);

# %%
sns.relplot(x="state", y="totalprod", kind="line", data=honey);

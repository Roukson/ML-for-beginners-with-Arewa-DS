# %% [markdown]
# Prince Rogers Nelson (June 7, 1958 – April 21, 2016), commonly known mononymously as Prince, was an American singer-songwriter, musician, and record producer. The recipient of numerous awards and nominations, he is widely regarded as one of the greatest musicians of all-time.[3][4] He was known for his flamboyant, androgynous persona;

# %% [markdown]
# ![image.png](attachment:image.png)
